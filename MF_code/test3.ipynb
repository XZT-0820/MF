# %%
from vnpy.alpha.lab import AlphaLab

from pathlib import Path
from datetime import datetime,timedelta
from vnpy.alpha import AlphaDataset

# %%
vt_index_symbol = "000300.SSE"
BASE_PATH = Path('D:/Aquant project/MF')
LAB_PATH = BASE_PATH / 'MFMF_lab'

# %%
# 获取MF_Lab
lab = AlphaLab(str(LAB_PATH))
DATASET_NAME = 'v3'
dataset: AlphaDataset = lab.load_dataset(DATASET_NAME)
print('yiwancheng')

# %%
print('jialeyige')

# %%
# 特征表现分析
dataset.show_feature_performance("corr_close_nextopen_lag_1")
# Out:
# C:\veighna_studio\Lib\site-packages\alphalens\utils.py:308: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = prices.pct_change(period)
# C:\veighna_studio\Lib\site-packages\alphalens\utils.py:308: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = prices.pct_change(period)
# ...
